# %% [markdown]
# # Image Classification
# In this project, you'll classify images from the [CIFAR-10 dataset](https://www.cs.toronto.edu/~kriz/cifar.html).  The dataset consists of airplanes, dogs, cats, and other objects. You'll preprocess the images, then train a convolutional neural network on all the samples. The images need to be normalized and the labels need to be one-hot encoded.  You'll get to apply what you learned and build a convolutional, max pooling, dropout, and fully connected layers.  At the end, you'll get to see your neural network's predictions on the sample images.
# ## Get the Data
# Run the following cell to download the [CIFAR-10 dataset for python](https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz).

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import problem_unittests as tests
import tarfile

cifar10_dataset_folder_path = 'cifar-10-batches-py'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile('cifar-10-python.tar.gz'):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc='CIFAR-10 Dataset') as pbar:
        urlretrieve(
            'https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz',
            'cifar-10-python.tar.gz',
            pbar.hook)

if not isdir(cifar10_dataset_folder_path):
    with tarfile.open('cifar-10-python.tar.gz') as tar:
        tar.extractall()
        tar.close()


tests.test_folder_path(cifar10_dataset_folder_path)
# Out:
# All files found!

# %% [markdown]
# ## Explore the Data
# The dataset is broken into batches to prevent your machine from running out of memory.  The CIFAR-10 dataset consists of 5 batches, named `data_batch_1`, `data_batch_2`, etc.. Each batch contains the labels and images that are one of the following:
# * airplane
# * automobile
# * bird
# * cat
# * deer
# * dog
# * frog
# * horse
# * ship
# * truck
#
# Understanding a dataset is part of making predictions on the data.  Play around with the code cell below by changing the `batch_id` and `sample_id`. The `batch_id` is the id for a batch (1-5). The `sample_id` is the id for a image and label pair in the batch.
#
# Ask yourself "What are all possible labels?", "What is the range of values for the image data?", "Are the labels in order or random?".  Answers to questions like these will help you preprocess the data and end up with better predictions.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import helper
import numpy as np

# Explore the dataset
batch_id = 1
sample_id = 100
helper.display_stats(cifar10_dataset_folder_path, batch_id, sample_id)
# Out:
# Stats of batch 1:
# Samples: 10000
# Label Counts: {0: 1005, 1: 974, 2: 1032, 3: 1016, 4: 999, 5: 937, 6: 1030, 7: 1001, 8: 1025, 9: 981}
# First 20 Labels: [6, 9, 9, 4, 1, 1, 2, 7, 8, 3, 4, 7, 7, 2, 9, 9, 9, 3, 2, 6]
#
# Example of Image 100:
# Image - Min Value: 30 Max Value: 242
# Image - Shape: (32, 32, 3)
# Label - Label Id: 8 Name: ship

# %% [markdown]
# ## Implement Preprocess Functions
# ### Normalize
# In the cell below, implement the `normalize` function to take in image data, `x`, and return it as a normalized Numpy array. The values should be in the range of 0 to 1, inclusive.  The return object should be the same shape as `x`.

# %%
def normalize(x):
    """
    Normalize a list of sample image data in the range of 0 to 1
    : x: List of image data.  The image shape is (32, 32, 3)
    : return: Numpy array of normalize data
    """
    # TODO: Implement Function
    return np.array(x) / 255.0


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_normalize(normalize)
# Out:
# Tests Passed

# %% [markdown]
# ### One-hot encode
# Just like the previous code cell, you'll be implementing a function for preprocessing.  This time, you'll implement the `one_hot_encode` function. The input, `x`, are a list of labels.  Implement the function to return the list of labels as One-Hot encoded Numpy array.  The possible values for labels are 0 to 9. The one-hot encoding function should return the same encoding for each value between each call to `one_hot_encode`.  Make sure to save the map of encodings outside the function.
#
# Hint: Don't reinvent the wheel.

# %%
def one_hot_encode(x):
    """
    One hot encode a list of sample labels. Return a one-hot encoded vector for each label.
    : x: List of sample Labels
    : return: Numpy array of one-hot encoded labels
    """
    # TODO: Implement Function
    y = np.eye(10)[x]
    return y


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_one_hot_encode(one_hot_encode)
# Out:
# Tests Passed

# %% [markdown]
# ### Randomize Data
# As you saw from exploring the data above, the order of the samples are randomized.  It doesn't hurt to randomize it again, but you don't need to for this dataset.

# %% [markdown]
# ## Preprocess all the data and save it
# Running the code cell below will preprocess all the CIFAR-10 data and save it to file. The code below also uses 10% of the training data for validation.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Preprocess Training, Validation, and Testing Data
helper.preprocess_and_save_data(cifar10_dataset_folder_path, normalize, one_hot_encode)

# %% [markdown]
# # Check Point
# This is your first checkpoint.  If you ever decide to come back to this notebook or have to restart the notebook, you can start from here.  The preprocessed data has been saved to disk.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import pickle
import problem_unittests as tests
import helper

# Load the Preprocessed Validation data
valid_features, valid_labels = pickle.load(open('preprocess_validation.p', mode='rb'))

# %% [markdown]
# ## Build the network
# For the neural network, you'll build each layer into a function.  Most of the code you've seen has been outside of functions. To test your code more thoroughly, we require that you put each layer in a function.  This allows us to give you better feedback and test for simple mistakes using our unittests before you submit your project.
#
# >**Note:** If you're finding it hard to dedicate enough time for this course each week, we've provided a small shortcut to this part of the project. In the next couple of problems, you'll have the option to use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages to build each layer, except the layers you build in the "Convolutional and Max Pooling Layer" section.  TF Layers is similar to Keras's and TFLearn's abstraction to layers, so it's easy to pickup.
#
# >However, if you would like to get the most out of this course, try to solve all the problems _without_ using anything from the TF Layers packages. You **can** still use classes from other packages that happen to have the same name as ones you find in TF Layers! For example, instead of using the TF Layers version of the `conv2d` class, [tf.layers.conv2d](https://www.tensorflow.org/api_docs/python/tf/layers/conv2d), you would want to use the TF Neural Network version of `conv2d`, [tf.nn.conv2d](https://www.tensorflow.org/api_docs/python/tf/nn/conv2d).
#
# Let's begin!
#
# ### Input
# The neural network needs to read the image data, one-hot encoded labels, and dropout keep probability. Implement the following functions
# * Implement `neural_net_image_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `image_shape` with batch size set to `None`.
#  * Name the TensorFlow placeholder "x" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_label_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `n_classes` with batch size set to `None`.
#  * Name the TensorFlow placeholder "y" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_keep_prob_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder) for dropout keep probability.
#  * Name the TensorFlow placeholder "keep_prob" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
#
# These names will be used at the end of the project to load your saved model.
#
# Note: `None` for shapes in TensorFlow allow for a dynamic size.

# %%
import tensorflow as tf

def neural_net_image_input(image_shape):
    """
    Return a Tensor for a bach of image input
    : image_shape: Shape of the images
    : return: Tensor for image input.
    """
    # TODO: Implement Function
    return tf.placeholder(tf.float32, [None, *image_shape], name = "x")


def neural_net_label_input(n_classes):
    """
    Return a Tensor for a batch of label input
    : n_classes: Number of classes
    : return: Tensor for label input.
    """
    # TODO: Implement Function
    return tf.placeholder(tf.float32, shape=[None,n_classes], name = "y")


def neural_net_keep_prob_input():
    """
    Return a Tensor for keep probability
    : return: Tensor for keep probability.
    """
    # TODO: Implement Function
    return tf.placeholder(tf.float32, name="keep_prob")


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tf.reset_default_graph()
tests.test_nn_image_inputs(neural_net_image_input)
tests.test_nn_label_inputs(neural_net_label_input)
tests.test_nn_keep_prob_inputs(neural_net_keep_prob_input)
# Out:
# Image Input Tests Passed.
# Label Input Tests Passed.
# Keep Prob Tests Passed.

# %% [markdown]
# ### Convolution and Max Pooling Layer
# Convolution layers have a lot of success with images. For this code cell, you should implement the function `conv2d_maxpool` to apply convolution then max pooling:
# * Create the weight and bias using `conv_ksize`, `conv_num_outputs` and the shape of `x_tensor`.
# * Apply a convolution to `x_tensor` using weight and `conv_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
# * Add bias
# * Add a nonlinear activation to the convolution.
# * Apply Max Pooling using `pool_ksize` and `pool_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
#
# **Note:** You **can't** use [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) for **this** layer, but you can still use TensorFlow's [Neural Network](https://www.tensorflow.org/api_docs/python/tf/nn) package. You may still use the shortcut option for all the **other** layers.

# %%
def conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides):
    """
    Apply convolution then max pooling to x_tensor
    :param x_tensor: TensorFlow Tensor
    :param conv_num_outputs: Number of outputs for the convolutional layer
    :param conv_ksize: kernal size 2-D Tuple for the convolutional layer
    :param conv_strides: Stride 2-D Tuple for convolution
    :param pool_ksize: kernal size 2-D Tuple for pool
    :param pool_strides: Stride 2-D Tuple for pool
    : return: A tensor that represents convolution and max pooling of x_tensor
    """
    # TODO: Implement Function
    in_depth = int(x_tensor.shape[3])
#     out_depth = conv_num_outputs
    w_shape = [*conv_ksize, in_depth, conv_num_outputs]
    W = tf.Variable(tf.truncated_normal(w_shape,stddev = 0.05))

    b = tf.Variable(tf.zeros(conv_num_outputs))

    conv_strides = [1,*conv_strides, 1]
    layer = tf.nn.conv2d(x_tensor, W,strides=conv_strides,padding='SAME')

    layer = tf.nn.bias_add(layer, b)

    layer = tf.nn.relu(layer)

    pool_ksize = [1, *pool_ksize, 1]
    pool_strides = [1, *pool_strides,1]
    layer = tf.nn.max_pool(layer, ksize=pool_ksize,strides=pool_strides,padding='SAME')

    return layer
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_con_pool(conv2d_maxpool)
# Out:
# Tests Passed

# %% [markdown]
# ### Flatten Layer
# Implement the `flatten` function to change the dimension of `x_tensor` from a 4-D tensor to a 2-D tensor.  The output should be the shape (*Batch Size*, *Flattened Image Size*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def flatten(x_tensor):
    """
    Flatten x_tensor to (Batch Size, Flattened Image Size)
    : x_tensor: A tensor of size (Batch Size, ...), where ... are the image dimensions.
    : return: A tensor of size (Batch Size, Flattened Image Size).
    """
    # TODO: Implement Function
    batch_size, *img_size = x_tensor.get_shape().as_list()
    img_size = img_size[0] * img_size[1] * img_size[2]
    return tf.reshape(x_tensor,[-1, img_size])

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_flatten(flatten)
# Out:
# Tests Passed

# %% [markdown]
# ### Fully-Connected Layer
# Implement the `fully_conn` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def fully_conn(x_tensor, num_outputs):
    """
    Apply a fully connected layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
    w_shape = (int(x_tensor.get_shape().as_list()[1]), num_outputs)
    w = tf.Variable(tf.random_normal(w_shape, stddev=0.1))
    b = tf.Variable(tf.zeros(num_outputs))
    x = tf.add(tf.matmul(x_tensor, w), b)
    x = tf.nn.relu(x)
    return x


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_fully_conn(fully_conn)
# Out:
# Tests Passed

# %% [markdown]
# ### Output Layer
# Implement the `output` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.
#
# **Note:** Activation, softmax, or cross entropy should **not** be applied to this.

# %%
def output(x_tensor, num_outputs):
    """
    Apply a output layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
    w_shape = [int(x_tensor.get_shape().as_list()[1]), num_outputs]
    output_weight = tf.Variable(tf.truncated_normal(w_shape, stddev=0.1))
    output_bias = tf.Variable(tf.zeros(num_outputs))
    output_layer = tf.add(tf.matmul(x_tensor, output_weight), output_bias)
    
    return output_layer

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_output(output)
# Out:
# Tests Passed

# %% [markdown]
# ### Create Convolutional Model
# Implement the function `conv_net` to create a convolutional neural network model. The function takes in a batch of images, `x`, and outputs logits.  Use the layers you created above to create this model:
#
# * Apply 1, 2, or 3 Convolution and Max Pool layers
# * Apply a Flatten Layer
# * Apply 1, 2, or 3 Fully Connected Layers
# * Apply an Output Layer
# * Return the output
# * Apply [TensorFlow's Dropout](https://www.tensorflow.org/api_docs/python/tf/nn/dropout) to one or more layers in the model using `keep_prob`.

# %%
def conv_net(x, keep_prob):
    """
    Create a convolutional neural network model
    : x: Placeholder tensor that holds image data.
    : keep_prob: Placeholder tensor that hold dropout keep probability.
    : return: Tensor that represents logits
    """
    # TODO: Apply 1, 2, or 3 Convolution and Max Pool layers
    #    Play around with different number of outputs, kernel size and stride
    # Function Definition from Above:
#    conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides)
    
    x = conv2d_maxpool(x, 32, (3, 3), (1, 1), (2, 2), (2, 2))
    x = conv2d_maxpool(x, 32, (3, 3), (2, 2), (2, 2), (2, 2))
    x = conv2d_maxpool(x, 64, (3, 3), (1, 1), (2, 2), (2, 2))
    

    # TODO: Apply a Flatten Layer
    # Function Definition from Above:
    #   flatten(x_tensor)
    x = flatten(x)
    

    # TODO: Apply 1, 2, or 3 Fully Connected Layers
    #    Play around with different number of outputs
    # Function Definition from Above:
    #  fully_conn(x_tensor, num_outputs)
    x = fully_conn(x, 512)
    x = tf.nn.dropout(x, keep_prob)
    x = fully_conn(x, 128)
    x = tf.nn.dropout(x, keep_prob)
    
    
    # TODO: Apply an Output Layer
    #    Set this to the number of classes
    # Function Definition from Above:
    #   output(x_tensor, num_outputs)
    num_outputs = 10
    out = output(x, num_outputs)

    
    # TODO: return output
    return out


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""

##############################
## Build the Neural Network ##
##############################

# Remove previous weights, bias, inputs, etc..
tf.reset_default_graph()

# Inputs
x = neural_net_image_input((32, 32, 3))
y = neural_net_label_input(10)
keep_prob = neural_net_keep_prob_input()

# Model
logits = conv_net(x, keep_prob)

# Name logits Tensor, so that is can be loaded from disk after training
logits = tf.identity(logits, name='logits')

# Loss and Optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=y))
optimizer = tf.train.AdamOptimizer().minimize(cost)

# Accuracy
correct_pred = tf.equal(tf.argmax(logits, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32), name='accuracy')

tests.test_conv_net(conv_net)
# Out:
# Neural Network Built!

# %% [markdown]
# ## Train the Neural Network
# ### Single Optimization
# Implement the function `train_neural_network` to do a single optimization.  The optimization should use `optimizer` to optimize in `session` with a `feed_dict` of the following:
# * `x` for image input
# * `y` for labels
# * `keep_prob` for keep probability for dropout
#
# This function will be called for each batch, so `tf.global_variables_initializer()` has already been called.
#
# Note: Nothing needs to be returned. This function is only optimizing the neural network.

# %%
def train_neural_network(session, optimizer, keep_probability, feature_batch, label_batch):
    """
    Optimize the session on a batch of images and labels
    : session: Current TensorFlow session
    : optimizer: TensorFlow optimizer function
    : keep_probability: keep probability
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    """
    # TODO: Implement Function
    session.run(optimizer, feed_dict = {x:feature_batch, y:label_batch, keep_prob:keep_probability})



"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_train_nn(train_neural_network)
# Out:
# Tests Passed

# %% [markdown]
# ### Show Stats
# Implement the function `print_stats` to print loss and validation accuracy.  Use the global variables `valid_features` and `valid_labels` to calculate validation accuracy.  Use a keep probability of `1.0` to calculate the loss and validation accuracy.

# %%
def print_stats(session, feature_batch, label_batch, cost, accuracy):
    """
    Print information about loss and validation accuracy
    : session: Current TensorFlow session
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    : cost: TensorFlow cost function
    : accuracy: TensorFlow accuracy function
    """
    # TODO: Implement Function
    loss = session.run(cost, feed_dict={
        x: feature_batch,
        y: label_batch,
        keep_prob: 1.
    })
    
    valid_accuracy = session.run(accuracy, feed_dict={
        x: valid_features,
        y: valid_labels,
        keep_prob: 1.
    })

    print('Loss: {:>10.4f} Validation Accuracy: {:.4f}'.format(loss, valid_accuracy))

# %% [markdown]
# ### Hyperparameters
# Tune the following parameters:
# * Set `epochs` to the number of iterations until the network stops learning or start overfitting
# * Set `batch_size` to the highest number that your machine has memory for.  Most people set them to common sizes of memory:
#  * 64
#  * 128
#  * 256
#  * ...
# * Set `keep_probability` to the probability of keeping a node using dropout

# %%
# TODO: Tune Parameters
epochs = 60
batch_size = 128
keep_probability = 0.6

# %% [markdown]
# ### Train on a Single CIFAR-10 Batch
# Instead of training the neural network on all the CIFAR-10 batches of data, let's use a single batch. This should save time while you iterate on the model to get a better accuracy.  Once the final validation accuracy is 50% or greater, run the model on all the data in the next section.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
print('Checking the Training on a Single Batch...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        batch_i = 1
        for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
            train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
        print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
        print_stats(sess, batch_features, batch_labels, cost, accuracy)
# Out:
# Checking the Training on a Single Batch...
# Epoch  1, CIFAR-10 Batch 1:  Loss:     2.1300 Validation Accuracy: 0.2548
# Epoch  2, CIFAR-10 Batch 1:  Loss:     1.9541 Validation Accuracy: 0.3296
# Epoch  3, CIFAR-10 Batch 1:  Loss:     1.7397 Validation Accuracy: 0.4122
# Epoch  4, CIFAR-10 Batch 1:  Loss:     1.5158 Validation Accuracy: 0.4502
# Epoch  5, CIFAR-10 Batch 1:  Loss:     1.4418 Validation Accuracy: 0.4746
# Epoch  6, CIFAR-10 Batch 1:  Loss:     1.2576 Validation Accuracy: 0.4932
# Epoch  7, CIFAR-10 Batch 1:  Loss:     1.1684 Validation Accuracy: 0.4922
# Epoch  8, CIFAR-10 Batch 1:  Loss:     1.0696 Validation Accuracy: 0.5042
# Epoch  9, CIFAR-10 Batch 1:  Loss:     1.0296 Validation Accuracy: 0.5136
# Epoch 10, CIFAR-10 Batch 1:  Loss:     1.0279 Validation Accuracy: 0.4962
# Epoch 11, CIFAR-10 Batch 1:  Loss:     0.8728 Validation Accuracy: 0.5172
# Epoch 12, CIFAR-10 Batch 1:  Loss:     0.8344 Validation Accuracy: 0.5218
# Epoch 13, CIFAR-10 Batch 1:  Loss:     0.7395 Validation Accuracy: 0.5408
# Epoch 14, CIFAR-10 Batch 1:  Loss:     0.7397 Validation Accuracy: 0.5298
# Epoch 15, CIFAR-10 Batch 1:  Loss:     0.6523 Validation Accuracy: 0.5452
# Epoch 16, CIFAR-10 Batch 1:  Loss:     0.6313 Validation Accuracy: 0.5460
# Epoch 17, CIFAR-10 Batch 1:  Loss:     0.5661 Validation Accuracy: 0.5612
# Epoch 18, CIFAR-10 Batch 1:  Loss:     0.5333 Validation Accuracy: 0.5528
# Epoch 19, CIFAR-10 Batch 1:  Loss:     0.4597 Validation Accuracy: 0.5494
# Epoch 20, CIFAR-10 Batch 1:  Loss:     0.4387 Validation Accuracy: 0.5574
# Epoch 21, CIFAR-10 Batch 1:  Loss:     0.3979 Validation Accuracy: 0.5664
# Epoch 22, CIFAR-10 Batch 1:  Loss:     0.3795 Validation Accuracy: 0.5732
# Epoch 23, CIFAR-10 Batch 1:  Loss:     0.3158 Validation Accuracy: 0.5644
# Epoch 24, CIFAR-10 Batch 1:  Loss:     0.3519 Validation Accuracy: 0.5622
# Epoch 25, CIFAR-10 Batch 1:  Loss:     0.3404 Validation Accuracy: 0.5514
# Epoch 26, CIFAR-10 Batch 1:  Loss:     0.2729 Validation Accuracy: 0.5578
# Epoch 27, CIFAR-10 Batch 1:  Loss:     0.2730 Validation Accuracy: 0.5578
# Epoch 28, CIFAR-10 Batch 1:  Loss:     0.2215 Validation Accuracy: 0.5636
# Epoch 29, CIFAR-10 Batch 1:  Loss:     0.2213 Validation Accuracy: 0.5574
# Epoch 30, CIFAR-10 Batch 1:  Loss:     0.2111 Validation Accuracy: 0.5412
# Epoch 31, CIFAR-10 Batch 1:  Loss:     0.1861 Validation Accuracy: 0.5328
# Epoch 32, CIFAR-10 Batch 1:  Loss:     0.1697 Validation Accuracy: 0.5390
# Epoch 33, CIFAR-10 Batch 1:  Loss:     0.1582 Validation Accuracy: 0.5406
# Epoch 34, CIFAR-10 Batch 1:  Loss:     0.1387 Validation Accuracy: 0.5538
# Epoch 35, CIFAR-10 Batch 1:  Loss:     0.1497 Validation Accuracy: 0.5514
# Epoch 36, CIFAR-10 Batch 1:  Loss:     0.1608 Validation Accuracy: 0.5406
# Epoch 37, CIFAR-10 Batch 1:  Loss:     0.1462 Validation Accuracy: 0.5500
# Epoch 38, CIFAR-10 Batch 1:  Loss:     0.0956 Validation Accuracy: 0.5530
# Epoch 39, CIFAR-10 Batch 1:  Loss:     0.0799 Validation Accuracy: 0.5564
# Epoch 40, CIFAR-10 Batch 1:  Loss:     0.0732 Validation Accuracy: 0.5522
# Epoch 41, CIFAR-10 Batch 1:  Loss:     0.0630 Validation Accuracy: 0.5540
# Epoch 42, CIFAR-10 Batch 1:  Loss:     0.0808 Validation Accuracy: 0.5280
# Epoch 43, CIFAR-10 Batch 1:  Loss:     0.0526 Validation Accuracy: 0.5404
# Epoch 44, CIFAR-10 Batch 1:  Loss:     0.0649 Validation Accuracy: 0.5486
# Epoch 45, CIFAR-10 Batch 1:  Loss:     0.0562 Validation Accuracy: 0.5454
# Epoch 46, CIFAR-10 Batch 1:  Loss:     0.0397 Validation Accuracy: 0.5484
# Epoch 47, CIFAR-10 Batch 1:  Loss:     0.0456 Validation Accuracy: 0.5464
# Epoch 48, CIFAR-10 Batch 1:  Loss:     0.0422 Validation Accuracy: 0.5466
# Epoch 49, CIFAR-10 Batch 1:  Loss:     0.0424 Validation Accuracy: 0.5586
# Epoch 50, CIFAR-10 Batch 1:  Loss:     0.0351 Validation Accuracy: 0.5400
# Epoch 51, CIFAR-10 Batch 1:  Loss:     0.0303 Validation Accuracy: 0.5508
# Epoch 52, CIFAR-10 Batch 1:  Loss:     0.0286 Validation Accuracy: 0.5508
# Epoch 53, CIFAR-10 Batch 1:  Loss:     0.0435 Validation Accuracy: 0.5502
# Epoch 54, CIFAR-10 Batch 1:  Loss:     0.0155 Validation Accuracy: 0.5486
# Epoch 55, CIFAR-10 Batch 1:  Loss:     0.0162 Validation Accuracy: 0.5472
# Epoch 56, CIFAR-10 Batch 1:  Loss:     0.0234 Validation Accuracy: 0.5312
# Epoch 57, CIFAR-10 Batch 1:  Loss:     0.0205 Validation Accuracy: 0.5270
# Epoch 58, CIFAR-10 Batch 1:  Loss:     0.0217 Validation Accuracy: 0.5312
# Epoch 59, CIFAR-10 Batch 1:  Loss:     0.0103 Validation Accuracy: 0.5476
# Epoch 60, CIFAR-10 Batch 1:  Loss:     0.0148 Validation Accuracy: 0.5436

# %% [markdown]
# ### Fully Train the Model
# Now that you got a good accuracy with a single CIFAR-10 batch, try it with all five batches.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
save_model_path = './image_classification'

print('Training...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        # Loop over all batches
        n_batches = 5
        for batch_i in range(1, n_batches + 1):
            for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
                train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
            print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
            print_stats(sess, batch_features, batch_labels, cost, accuracy)
            
    # Save Model
    saver = tf.train.Saver()
    save_path = saver.save(sess, save_model_path)
# Out:
# Training...
# Epoch  1, CIFAR-10 Batch 1:  Loss:     2.1894 Validation Accuracy: 0.2468
# Epoch  1, CIFAR-10 Batch 2:  Loss:     1.8216 Validation Accuracy: 0.3424
# Epoch  1, CIFAR-10 Batch 3:  Loss:     1.6110 Validation Accuracy: 0.3766
# Epoch  1, CIFAR-10 Batch 4:  Loss:     1.5772 Validation Accuracy: 0.4218
# Epoch  1, CIFAR-10 Batch 5:  Loss:     1.6275 Validation Accuracy: 0.4362
# Epoch  2, CIFAR-10 Batch 1:  Loss:     1.7333 Validation Accuracy: 0.4560
# Epoch  2, CIFAR-10 Batch 2:  Loss:     1.5169 Validation Accuracy: 0.4464
# Epoch  2, CIFAR-10 Batch 3:  Loss:     1.1921 Validation Accuracy: 0.4920
# Epoch  2, CIFAR-10 Batch 4:  Loss:     1.3100 Validation Accuracy: 0.5078
# Epoch  2, CIFAR-10 Batch 5:  Loss:     1.4272 Validation Accuracy: 0.5106
# Epoch  3, CIFAR-10 Batch 1:  Loss:     1.3595 Validation Accuracy: 0.5354
# Epoch  3, CIFAR-10 Batch 2:  Loss:     1.1886 Validation Accuracy: 0.5064
# Epoch  3, CIFAR-10 Batch 3:  Loss:     1.0526 Validation Accuracy: 0.5460
# Epoch  3, CIFAR-10 Batch 4:  Loss:     1.0968 Validation Accuracy: 0.5552
# Epoch  3, CIFAR-10 Batch 5:  Loss:     1.1953 Validation Accuracy: 0.5652
# Epoch  4, CIFAR-10 Batch 1:  Loss:     1.1627 Validation Accuracy: 0.5696
# Epoch  4, CIFAR-10 Batch 2:  Loss:     1.0821 Validation Accuracy: 0.5312
# Epoch  4, CIFAR-10 Batch 3:  Loss:     0.9476 Validation Accuracy: 0.5798
# Epoch  4, CIFAR-10 Batch 4:  Loss:     0.9566 Validation Accuracy: 0.5864
# Epoch  4, CIFAR-10 Batch 5:  Loss:     1.0294 Validation Accuracy: 0.5920
# Epoch  5, CIFAR-10 Batch 1:  Loss:     0.9871 Validation Accuracy: 0.6000
# Epoch  5, CIFAR-10 Batch 2:  Loss:     0.9532 Validation Accuracy: 0.5974
# Epoch  5, CIFAR-10 Batch 3:  Loss:     0.8320 Validation Accuracy: 0.5912
# Epoch  5, CIFAR-10 Batch 4:  Loss:     0.8874 Validation Accuracy: 0.5992
# Epoch  5, CIFAR-10 Batch 5:  Loss:     0.8754 Validation Accuracy: 0.6092
# Epoch  6, CIFAR-10 Batch 1:  Loss:     0.9111 Validation Accuracy: 0.6054
# Epoch  6, CIFAR-10 Batch 2:  Loss:     0.9049 Validation Accuracy: 0.6102
# Epoch  6, CIFAR-10 Batch 3:  Loss:     0.8525 Validation Accuracy: 0.6072
# Epoch  6, CIFAR-10 Batch 4:  Loss:     0.7736 Validation Accuracy: 0.6262
# Epoch  6, CIFAR-10 Batch 5:  Loss:     0.7439 Validation Accuracy: 0.6374
# Epoch  7, CIFAR-10 Batch 1:  Loss:     0.7906 Validation Accuracy: 0.6282
# Epoch  7, CIFAR-10 Batch 2:  Loss:     0.8420 Validation Accuracy: 0.6216
# Epoch  7, CIFAR-10 Batch 3:  Loss:     0.6717 Validation Accuracy: 0.6288
# Epoch  7, CIFAR-10 Batch 4:  Loss:     0.7371 Validation Accuracy: 0.6246
# Epoch  7, CIFAR-10 Batch 5:  Loss:     0.7158 Validation Accuracy: 0.6406
# Epoch  8, CIFAR-10 Batch 1:  Loss:     0.7654 Validation Accuracy: 0.6422
# Epoch  8, CIFAR-10 Batch 2:  Loss:     0.7681 Validation Accuracy: 0.6226
# Epoch  8, CIFAR-10 Batch 3:  Loss:     0.6079 Validation Accuracy: 0.6398
# Epoch  8, CIFAR-10 Batch 4:  Loss:     0.7141 Validation Accuracy: 0.6400
# Epoch  8, CIFAR-10 Batch 5:  Loss:     0.6352 Validation Accuracy: 0.6418
# Epoch  9, CIFAR-10 Batch 1:  Loss:     0.6860 Validation Accuracy: 0.6442
# Epoch  9, CIFAR-10 Batch 2:  Loss:     0.6528 Validation Accuracy: 0.6386
# Epoch  9, CIFAR-10 Batch 3:  Loss:     0.4821 Validation Accuracy: 0.6514
# Epoch  9, CIFAR-10 Batch 4:  Loss:     0.6409 Validation Accuracy: 0.6540
# Epoch  9, CIFAR-10 Batch 5:  Loss:     0.5333 Validation Accuracy: 0.6344
# Epoch 10, CIFAR-10 Batch 1:  Loss:     0.7007 Validation Accuracy: 0.6344
# Epoch 10, CIFAR-10 Batch 2:  Loss:     0.5863 Validation Accuracy: 0.6556
# Epoch 10, CIFAR-10 Batch 3:  Loss:     0.4618 Validation Accuracy: 0.6476
# Epoch 10, CIFAR-10 Batch 4:  Loss:     0.5561 Validation Accuracy: 0.6520
# Epoch 10, CIFAR-10 Batch 5:  Loss:     0.4866 Validation Accuracy: 0.6514
# Epoch 11, CIFAR-10 Batch 1:  Loss:     0.5921 Validation Accuracy: 0.6668
# Epoch 11, CIFAR-10 Batch 2:  Loss:     0.5386 Validation Accuracy: 0.6498
# Epoch 11, CIFAR-10 Batch 3:  Loss:     0.4091 Validation Accuracy: 0.6632
# Epoch 11, CIFAR-10 Batch 4:  Loss:     0.5199 Validation Accuracy: 0.6696
# Epoch 11, CIFAR-10 Batch 5:  Loss:     0.4521 Validation Accuracy: 0.6586
# Epoch 12, CIFAR-10 Batch 1:  Loss:     0.6148 Validation Accuracy: 0.6638
# Epoch 12, CIFAR-10 Batch 2:  Loss:     0.4531 Validation Accuracy: 0.6566
# Epoch 12, CIFAR-10 Batch 3:  Loss:     0.3514 Validation Accuracy: 0.6698
# Epoch 12, CIFAR-10 Batch 4:  Loss:     0.5064 Validation Accuracy: 0.6780
# Epoch 12, CIFAR-10 Batch 5:  Loss:     0.4460 Validation Accuracy: 0.6600
# Epoch 13, CIFAR-10 Batch 1:  Loss:     0.5273 Validation Accuracy: 0.6692
# Epoch 13, CIFAR-10 Batch 2:  Loss:     0.4438 Validation Accuracy: 0.6718
# Epoch 13, CIFAR-10 Batch 3:  Loss:     0.2984 Validation Accuracy: 0.6768
# Epoch 13, CIFAR-10 Batch 4:  Loss:     0.4965 Validation Accuracy: 0.6646
# Epoch 13, CIFAR-10 Batch 5:  Loss:     0.3677 Validation Accuracy: 0.6546
# Epoch 14, CIFAR-10 Batch 1:  Loss:     0.4656 Validation Accuracy: 0.6690
# Epoch 14, CIFAR-10 Batch 2:  Loss:     0.4153 Validation Accuracy: 0.6734
# Epoch 14, CIFAR-10 Batch 3:  Loss:     0.2608 Validation Accuracy: 0.6832
# Epoch 14, CIFAR-10 Batch 4:  Loss:     0.3954 Validation Accuracy: 0.6902
# Epoch 14, CIFAR-10 Batch 5:  Loss:     0.3417 Validation Accuracy: 0.6658
# Epoch 15, CIFAR-10 Batch 1:  Loss:     0.4790 Validation Accuracy: 0.6774
# Epoch 15, CIFAR-10 Batch 2:  Loss:     0.3692 Validation Accuracy: 0.6796
# Epoch 15, CIFAR-10 Batch 3:  Loss:     0.3343 Validation Accuracy: 0.6646
# Epoch 15, CIFAR-10 Batch 4:  Loss:     0.3755 Validation Accuracy: 0.6842
# Epoch 15, CIFAR-10 Batch 5:  Loss:     0.2976 Validation Accuracy: 0.6708
# Epoch 16, CIFAR-10 Batch 1:  Loss:     0.4263 Validation Accuracy: 0.6840
# Epoch 16, CIFAR-10 Batch 2:  Loss:     0.4127 Validation Accuracy: 0.6832
# Epoch 16, CIFAR-10 Batch 3:  Loss:     0.2841 Validation Accuracy: 0.6804
# Epoch 16, CIFAR-10 Batch 4:  Loss:     0.3211 Validation Accuracy: 0.6832
# Epoch 16, CIFAR-10 Batch 5:  Loss:     0.3071 Validation Accuracy: 0.6696
# Epoch 17, CIFAR-10 Batch 1:  Loss:     0.4105 Validation Accuracy: 0.6876
# Epoch 17, CIFAR-10 Batch 2:  Loss:     0.3452 Validation Accuracy: 0.6758
# Epoch 17, CIFAR-10 Batch 3:  Loss:     0.2067 Validation Accuracy: 0.6816
# Epoch 17, CIFAR-10 Batch 4:  Loss:     0.3496 Validation Accuracy: 0.6840
# Epoch 17, CIFAR-10 Batch 5:  Loss:     0.2436 Validation Accuracy: 0.6748
# Epoch 18, CIFAR-10 Batch 1:  Loss:     0.4086 Validation Accuracy: 0.6830
# Epoch 18, CIFAR-10 Batch 2:  Loss:     0.3323 Validation Accuracy: 0.6712
# Epoch 18, CIFAR-10 Batch 3:  Loss:     0.2140 Validation Accuracy: 0.6678
# Epoch 18, CIFAR-10 Batch 4:  Loss:     0.2663 Validation Accuracy: 0.6798
# Epoch 18, CIFAR-10 Batch 5:  Loss:     0.2186 Validation Accuracy: 0.6784
# Epoch 19, CIFAR-10 Batch 1:  Loss:     0.3540 Validation Accuracy: 0.6796
# Epoch 19, CIFAR-10 Batch 2:  Loss:     0.3168 Validation Accuracy: 0.6738
# Epoch 19, CIFAR-10 Batch 3:  Loss:     0.1855 Validation Accuracy: 0.6826
# Epoch 19, CIFAR-10 Batch 4:  Loss:     0.2753 Validation Accuracy: 0.6858
# Epoch 19, CIFAR-10 Batch 5:  Loss:     0.2035 Validation Accuracy: 0.6746
# Epoch 20, CIFAR-10 Batch 1:  Loss:     0.3519 Validation Accuracy: 0.6814
# Epoch 20, CIFAR-10 Batch 2:  Loss:     0.2554 Validation Accuracy: 0.6784
# Epoch 20, CIFAR-10 Batch 3:  Loss:     0.1935 Validation Accuracy: 0.6896
# Epoch 20, CIFAR-10 Batch 4:  Loss:     0.2649 Validation Accuracy: 0.6756
# Epoch 20, CIFAR-10 Batch 5:  Loss:     0.1739 Validation Accuracy: 0.6730
# Epoch 21, CIFAR-10 Batch 1:  Loss:     0.3961 Validation Accuracy: 0.6780
# Epoch 21, CIFAR-10 Batch 2:  Loss:     0.2463 Validation Accuracy: 0.6800
# Epoch 21, CIFAR-10 Batch 3:  Loss:     0.1680 Validation Accuracy: 0.6852
# Epoch 21, CIFAR-10 Batch 4:  Loss:     0.2460 Validation Accuracy: 0.6784
# Epoch 21, CIFAR-10 Batch 5:  Loss:     0.1759 Validation Accuracy: 0.6774
# Epoch 22, CIFAR-10 Batch 1:  Loss:     0.3138 Validation Accuracy: 0.6692
# Epoch 22, CIFAR-10 Batch 2:  Loss:     0.2595 Validation Accuracy: 0.6746
# Epoch 22, CIFAR-10 Batch 3:  Loss:     0.1593 Validation Accuracy: 0.6912
# Epoch 22, CIFAR-10 Batch 4:  Loss:     0.2262 Validation Accuracy: 0.6792
# Epoch 22, CIFAR-10 Batch 5:  Loss:     0.1826 Validation Accuracy: 0.6940
# Epoch 23, CIFAR-10 Batch 1:  Loss:     0.3371 Validation Accuracy: 0.6790
# Epoch 23, CIFAR-10 Batch 2:  Loss:     0.2256 Validation Accuracy: 0.6774
# Epoch 23, CIFAR-10 Batch 3:  Loss:     0.1642 Validation Accuracy: 0.6890
# Epoch 23, CIFAR-10 Batch 4:  Loss:     0.2845 Validation Accuracy: 0.6688
# Epoch 23, CIFAR-10 Batch 5:  Loss:     0.1354 Validation Accuracy: 0.6868
# Epoch 24, CIFAR-10 Batch 1:  Loss:     0.3051 Validation Accuracy: 0.6768
# Epoch 24, CIFAR-10 Batch 2:  Loss:     0.2165 Validation Accuracy: 0.6764
# Epoch 24, CIFAR-10 Batch 3:  Loss:     0.1521 Validation Accuracy: 0.6902
# Epoch 24, CIFAR-10 Batch 4:  Loss:     0.2522 Validation Accuracy: 0.6656
# Epoch 24, CIFAR-10 Batch 5:  Loss:     0.1259 Validation Accuracy: 0.6844
# Epoch 25, CIFAR-10 Batch 1:  Loss:     0.2821 Validation Accuracy: 0.6800
# Epoch 25, CIFAR-10 Batch 2:  Loss:     0.2343 Validation Accuracy: 0.6806
# Epoch 25, CIFAR-10 Batch 3:  Loss:     0.1498 Validation Accuracy: 0.6792
# Epoch 25, CIFAR-10 Batch 4:  Loss:     0.2909 Validation Accuracy: 0.6558
# Epoch 25, CIFAR-10 Batch 5:  Loss:     0.1645 Validation Accuracy: 0.6748
# Epoch 26, CIFAR-10 Batch 1:  Loss:     0.2395 Validation Accuracy: 0.6782
# Epoch 26, CIFAR-10 Batch 2:  Loss:     0.2078 Validation Accuracy: 0.6756
# Epoch 26, CIFAR-10 Batch 3:  Loss:     0.1517 Validation Accuracy: 0.6838
# Epoch 26, CIFAR-10 Batch 4:  Loss:     0.2600 Validation Accuracy: 0.6692
# Epoch 26, CIFAR-10 Batch 5:  Loss:     0.1258 Validation Accuracy: 0.6810
# Epoch 27, CIFAR-10 Batch 1:  Loss:     0.2125 Validation Accuracy: 0.6796
# Epoch 27, CIFAR-10 Batch 2:  Loss:     0.1749 Validation Accuracy: 0.6758
# Epoch 27, CIFAR-10 Batch 3:  Loss:     0.1286 Validation Accuracy: 0.6886
# Epoch 27, CIFAR-10 Batch 4:  Loss:     0.2565 Validation Accuracy: 0.6688
# Epoch 27, CIFAR-10 Batch 5:  Loss:     0.1264 Validation Accuracy: 0.6846
# Epoch 28, CIFAR-10 Batch 1:  Loss:     0.2304 Validation Accuracy: 0.6838
# Epoch 28, CIFAR-10 Batch 2:  Loss:     0.1515 Validation Accuracy: 0.6832
# Epoch 28, CIFAR-10 Batch 3:  Loss:     0.1482 Validation Accuracy: 0.6936
# Epoch 28, CIFAR-10 Batch 4:  Loss:     0.2604 Validation Accuracy: 0.6516
# Epoch 28, CIFAR-10 Batch 5:  Loss:     0.1416 Validation Accuracy: 0.6696
# Epoch 29, CIFAR-10 Batch 1:  Loss:     0.2295 Validation Accuracy: 0.6706
# Epoch 29, CIFAR-10 Batch 2:  Loss:     0.1417 Validation Accuracy: 0.6778
# Epoch 29, CIFAR-10 Batch 3:  Loss:     0.1117 Validation Accuracy: 0.6906
# Epoch 29, CIFAR-10 Batch 4:  Loss:     0.2502 Validation Accuracy: 0.6638
# Epoch 29, CIFAR-10 Batch 5:  Loss:     0.1047 Validation Accuracy: 0.6784
# Epoch 30, CIFAR-10 Batch 1:  Loss:     0.2332 Validation Accuracy: 0.6802
# Epoch 30, CIFAR-10 Batch 2:  Loss:     0.1487 Validation Accuracy: 0.6754
# Epoch 30, CIFAR-10 Batch 3:  Loss:     0.1286 Validation Accuracy: 0.6938
# Epoch 30, CIFAR-10 Batch 4:  Loss:     0.1986 Validation Accuracy: 0.6742
# Epoch 30, CIFAR-10 Batch 5:  Loss:     0.0921 Validation Accuracy: 0.6870
# Epoch 31, CIFAR-10 Batch 1:  Loss:     0.2137 Validation Accuracy: 0.6858
# Epoch 31, CIFAR-10 Batch 2:  Loss:     0.1384 Validation Accuracy: 0.6864
# Epoch 31, CIFAR-10 Batch 3:  Loss:     0.1523 Validation Accuracy: 0.6886
# Epoch 31, CIFAR-10 Batch 4:  Loss:     0.1761 Validation Accuracy: 0.6768
# Epoch 31, CIFAR-10 Batch 5:  Loss:     0.1049 Validation Accuracy: 0.6822
# Epoch 32, CIFAR-10 Batch 1:  Loss:     0.2255 Validation Accuracy: 0.6808
# Epoch 32, CIFAR-10 Batch 2:  Loss:     0.1333 Validation Accuracy: 0.6838
# Epoch 32, CIFAR-10 Batch 3:  Loss:     0.1146 Validation Accuracy: 0.6904
# Epoch 32, CIFAR-10 Batch 4:  Loss:     0.1738 Validation Accuracy: 0.6750
# Epoch 32, CIFAR-10 Batch 5:  Loss:     0.0857 Validation Accuracy: 0.6892
# Epoch 33, CIFAR-10 Batch 1:  Loss:     0.2444 Validation Accuracy: 0.6780
# Epoch 33, CIFAR-10 Batch 2:  Loss:     0.1185 Validation Accuracy: 0.6902
# Epoch 33, CIFAR-10 Batch 3:  Loss:     0.0973 Validation Accuracy: 0.6930
# Epoch 33, CIFAR-10 Batch 4:  Loss:     0.1393 Validation Accuracy: 0.6680
# Epoch 33, CIFAR-10 Batch 5:  Loss:     0.1070 Validation Accuracy: 0.6794
# Epoch 34, CIFAR-10 Batch 1:  Loss:     0.2295 Validation Accuracy: 0.6770
# Epoch 34, CIFAR-10 Batch 2:  Loss:     0.1173 Validation Accuracy: 0.6944
# Epoch 34, CIFAR-10 Batch 3:  Loss:     0.1139 Validation Accuracy: 0.6814
# Epoch 34, CIFAR-10 Batch 4:  Loss:     0.1523 Validation Accuracy: 0.6696
# Epoch 34, CIFAR-10 Batch 5:  Loss:     0.0866 Validation Accuracy: 0.6832
# Epoch 35, CIFAR-10 Batch 1:  Loss:     0.2300 Validation Accuracy: 0.6728
# Epoch 35, CIFAR-10 Batch 2:  Loss:     0.1186 Validation Accuracy: 0.6890
# Epoch 35, CIFAR-10 Batch 3:  Loss:     0.1240 Validation Accuracy: 0.6872
# Epoch 35, CIFAR-10 Batch 4:  Loss:     0.1563 Validation Accuracy: 0.6774
# Epoch 35, CIFAR-10 Batch 5:  Loss:     0.0661 Validation Accuracy: 0.6830
# Epoch 36, CIFAR-10 Batch 1:  Loss:     0.1581 Validation Accuracy: 0.6876
# Epoch 36, CIFAR-10 Batch 2:  Loss:     0.0896 Validation Accuracy: 0.6856
# Epoch 36, CIFAR-10 Batch 3:  Loss:     0.0832 Validation Accuracy: 0.6718
# Epoch 36, CIFAR-10 Batch 4:  Loss:     0.1165 Validation Accuracy: 0.6784
# Epoch 36, CIFAR-10 Batch 5:  Loss:     0.0708 Validation Accuracy: 0.6762
# Epoch 37, CIFAR-10 Batch 1:  Loss:     0.1673 Validation Accuracy: 0.6812
# Epoch 37, CIFAR-10 Batch 2:  Loss:     0.0883 Validation Accuracy: 0.6732
# Epoch 37, CIFAR-10 Batch 3:  Loss:     0.0780 Validation Accuracy: 0.6850
# Epoch 37, CIFAR-10 Batch 4:  Loss:     0.1191 Validation Accuracy: 0.6866
# Epoch 37, CIFAR-10 Batch 5:  Loss:     0.0684 Validation Accuracy: 0.6752
# Epoch 38, CIFAR-10 Batch 1:  Loss:     0.1619 Validation Accuracy: 0.6844
# Epoch 38, CIFAR-10 Batch 2:  Loss:     0.0791 Validation Accuracy: 0.6858
# Epoch 38, CIFAR-10 Batch 3:  Loss:     0.1020 Validation Accuracy: 0.6758
# Epoch 38, CIFAR-10 Batch 4:  Loss:     0.1174 Validation Accuracy: 0.6824
# Epoch 38, CIFAR-10 Batch 5:  Loss:     0.0566 Validation Accuracy: 0.6756
# Epoch 39, CIFAR-10 Batch 1:  Loss:     0.1629 Validation Accuracy: 0.6764
# Epoch 39, CIFAR-10 Batch 2:  Loss:     0.1094 Validation Accuracy: 0.6864
# Epoch 39, CIFAR-10 Batch 3:  Loss:     0.0999 Validation Accuracy: 0.6620
# Epoch 39, CIFAR-10 Batch 4:  Loss:     0.0983 Validation Accuracy: 0.6846
# Epoch 39, CIFAR-10 Batch 5:  Loss:     0.0725 Validation Accuracy: 0.6706
# Epoch 40, CIFAR-10 Batch 1:  Loss:     0.1626 Validation Accuracy: 0.6864
# Epoch 40, CIFAR-10 Batch 2:  Loss:     0.0999 Validation Accuracy: 0.6710
# Epoch 40, CIFAR-10 Batch 3:  Loss:     0.0830 Validation Accuracy: 0.6776
# Epoch 40, CIFAR-10 Batch 4:  Loss:     0.0964 Validation Accuracy: 0.6754
# Epoch 40, CIFAR-10 Batch 5:  Loss:     0.0667 Validation Accuracy: 0.6826
# Epoch 41, CIFAR-10 Batch 1:  Loss:     0.1483 Validation Accuracy: 0.6932
# Epoch 41, CIFAR-10 Batch 2:  Loss:     0.0939 Validation Accuracy: 0.6806
# Epoch 41, CIFAR-10 Batch 3:  Loss:     0.1050 Validation Accuracy: 0.6644
# Epoch 41, CIFAR-10 Batch 4:  Loss:     0.0958 Validation Accuracy: 0.6828
# Epoch 41, CIFAR-10 Batch 5:  Loss:     0.0516 Validation Accuracy: 0.6808
# Epoch 42, CIFAR-10 Batch 1:  Loss:     0.1535 Validation Accuracy: 0.6846
# Epoch 42, CIFAR-10 Batch 2:  Loss:     0.0883 Validation Accuracy: 0.6832
# Epoch 42, CIFAR-10 Batch 3:  Loss:     0.0836 Validation Accuracy: 0.6678
# Epoch 42, CIFAR-10 Batch 4:  Loss:     0.0965 Validation Accuracy: 0.6802
# Epoch 42, CIFAR-10 Batch 5:  Loss:     0.0604 Validation Accuracy: 0.6778
# Epoch 43, CIFAR-10 Batch 1:  Loss:     0.1153 Validation Accuracy: 0.6878
# Epoch 43, CIFAR-10 Batch 2:  Loss:     0.0754 Validation Accuracy: 0.6814
# Epoch 43, CIFAR-10 Batch 3:  Loss:     0.0785 Validation Accuracy: 0.6814
# Epoch 43, CIFAR-10 Batch 4:  Loss:     0.1045 Validation Accuracy: 0.6742
# Epoch 43, CIFAR-10 Batch 5:  Loss:     0.0548 Validation Accuracy: 0.6912
# Epoch 44, CIFAR-10 Batch 1:  Loss:     0.1281 Validation Accuracy: 0.6806
# Epoch 44, CIFAR-10 Batch 2:  Loss:     0.0788 Validation Accuracy: 0.6780
# Epoch 44, CIFAR-10 Batch 3:  Loss:     0.0563 Validation Accuracy: 0.6836
# Epoch 44, CIFAR-10 Batch 4:  Loss:     0.1232 Validation Accuracy: 0.6816
# Epoch 44, CIFAR-10 Batch 5:  Loss:     0.0680 Validation Accuracy: 0.6864
# Epoch 45, CIFAR-10 Batch 1:  Loss:     0.1327 Validation Accuracy: 0.6838
# Epoch 45, CIFAR-10 Batch 2:  Loss:     0.0807 Validation Accuracy: 0.6750
# Epoch 45, CIFAR-10 Batch 3:  Loss:     0.0733 Validation Accuracy: 0.6800
# Epoch 45, CIFAR-10 Batch 4:  Loss:     0.0757 Validation Accuracy: 0.6830
# Epoch 45, CIFAR-10 Batch 5:  Loss:     0.0560 Validation Accuracy: 0.6912
# Epoch 46, CIFAR-10 Batch 1:  Loss:     0.1277 Validation Accuracy: 0.6850
# Epoch 46, CIFAR-10 Batch 2:  Loss:     0.0750 Validation Accuracy: 0.6822
# Epoch 46, CIFAR-10 Batch 3:  Loss:     0.0835 Validation Accuracy: 0.6748
# Epoch 46, CIFAR-10 Batch 4:  Loss:     0.0849 Validation Accuracy: 0.6856
# Epoch 46, CIFAR-10 Batch 5:  Loss:     0.0527 Validation Accuracy: 0.6856
# Epoch 47, CIFAR-10 Batch 1:  Loss:     0.1051 Validation Accuracy: 0.6778
# Epoch 47, CIFAR-10 Batch 2:  Loss:     0.0772 Validation Accuracy: 0.6804
# Epoch 47, CIFAR-10 Batch 3:  Loss:     0.0715 Validation Accuracy: 0.6748
# Epoch 47, CIFAR-10 Batch 4:  Loss:     0.0875 Validation Accuracy: 0.6784
# Epoch 47, CIFAR-10 Batch 5:  Loss:     0.0495 Validation Accuracy: 0.6864
# Epoch 48, CIFAR-10 Batch 1:  Loss:     0.1065 Validation Accuracy: 0.6910
# Epoch 48, CIFAR-10 Batch 2:  Loss:     0.0871 Validation Accuracy: 0.6780
# Epoch 48, CIFAR-10 Batch 3:  Loss:     0.0709 Validation Accuracy: 0.6828
# Epoch 48, CIFAR-10 Batch 4:  Loss:     0.0647 Validation Accuracy: 0.6758
# Epoch 48, CIFAR-10 Batch 5:  Loss:     0.0584 Validation Accuracy: 0.6878
# Epoch 49, CIFAR-10 Batch 1:  Loss:     0.0933 Validation Accuracy: 0.6858
# Epoch 49, CIFAR-10 Batch 2:  Loss:     0.0792 Validation Accuracy: 0.6758
# Epoch 49, CIFAR-10 Batch 3:  Loss:     0.0776 Validation Accuracy: 0.6814
# Epoch 49, CIFAR-10 Batch 4:  Loss:     0.0814 Validation Accuracy: 0.6818
# Epoch 49, CIFAR-10 Batch 5:  Loss:     0.0366 Validation Accuracy: 0.6804
# Epoch 50, CIFAR-10 Batch 1:  Loss:     0.0839 Validation Accuracy: 0.6806
# Epoch 50, CIFAR-10 Batch 2:  Loss:     0.0707 Validation Accuracy: 0.6858
# Epoch 50, CIFAR-10 Batch 3:  Loss:     0.0564 Validation Accuracy: 0.6694
# Epoch 50, CIFAR-10 Batch 4:  Loss:     0.0604 Validation Accuracy: 0.6888
# Epoch 50, CIFAR-10 Batch 5:  Loss:     0.0278 Validation Accuracy: 0.6878
# Epoch 51, CIFAR-10 Batch 1:  Loss:     0.0971 Validation Accuracy: 0.6842
# Epoch 51, CIFAR-10 Batch 2:  Loss:     0.0655 Validation Accuracy: 0.6770
# Epoch 51, CIFAR-10 Batch 3:  Loss:     0.0614 Validation Accuracy: 0.6800
# Epoch 51, CIFAR-10 Batch 4:  Loss:     0.0513 Validation Accuracy: 0.6876
# Epoch 51, CIFAR-10 Batch 5:  Loss:     0.0401 Validation Accuracy: 0.6928
# Epoch 52, CIFAR-10 Batch 1:  Loss:     0.0890 Validation Accuracy: 0.6836
# Epoch 52, CIFAR-10 Batch 2:  Loss:     0.0713 Validation Accuracy: 0.6836
# Epoch 52, CIFAR-10 Batch 3:  Loss:     0.0602 Validation Accuracy: 0.6844
# Epoch 52, CIFAR-10 Batch 4:  Loss:     0.0494 Validation Accuracy: 0.6952
# Epoch 52, CIFAR-10 Batch 5:  Loss:     0.0252 Validation Accuracy: 0.6916
# Epoch 53, CIFAR-10 Batch 1:  Loss:     0.0967 Validation Accuracy: 0.6880
# Epoch 53, CIFAR-10 Batch 2:  Loss:     0.0739 Validation Accuracy: 0.6814
# Epoch 53, CIFAR-10 Batch 3:  Loss:     0.0670 Validation Accuracy: 0.6924
# Epoch 53, CIFAR-10 Batch 4:  Loss:     0.0531 Validation Accuracy: 0.6928
# Epoch 53, CIFAR-10 Batch 5:  Loss:     0.0324 Validation Accuracy: 0.6870
# Epoch 54, CIFAR-10 Batch 1:  Loss:     0.0873 Validation Accuracy: 0.6874
# Epoch 54, CIFAR-10 Batch 2:  Loss:     0.0629 Validation Accuracy: 0.6838
# Epoch 54, CIFAR-10 Batch 3:  Loss:     0.0613 Validation Accuracy: 0.6720
# Epoch 54, CIFAR-10 Batch 4:  Loss:     0.0513 Validation Accuracy: 0.6900
# Epoch 54, CIFAR-10 Batch 5:  Loss:     0.0248 Validation Accuracy: 0.6838
# Epoch 55, CIFAR-10 Batch 1:  Loss:     0.0738 Validation Accuracy: 0.6932
# Epoch 55, CIFAR-10 Batch 2:  Loss:     0.0565 Validation Accuracy: 0.6882
# Epoch 55, CIFAR-10 Batch 3:  Loss:     0.0692 Validation Accuracy: 0.6848
# Epoch 55, CIFAR-10 Batch 4:  Loss:     0.0456 Validation Accuracy: 0.6880
# Epoch 55, CIFAR-10 Batch 5:  Loss:     0.0385 Validation Accuracy: 0.6772
# Epoch 56, CIFAR-10 Batch 1:  Loss:     0.0970 Validation Accuracy: 0.6924
# Epoch 56, CIFAR-10 Batch 2:  Loss:     0.0388 Validation Accuracy: 0.6832
# Epoch 56, CIFAR-10 Batch 3:  Loss:     0.0507 Validation Accuracy: 0.6900
# Epoch 56, CIFAR-10 Batch 4:  Loss:     0.0526 Validation Accuracy: 0.6916
# Epoch 56, CIFAR-10 Batch 5:  Loss:     0.0339 Validation Accuracy: 0.6878
# Epoch 57, CIFAR-10 Batch 1:  Loss:     0.0686 Validation Accuracy: 0.6890
# Epoch 57, CIFAR-10 Batch 2:  Loss:     0.0669 Validation Accuracy: 0.6684
# Epoch 57, CIFAR-10 Batch 3:  Loss:     0.0575 Validation Accuracy: 0.6898
# Epoch 57, CIFAR-10 Batch 4:  Loss:     0.0580 Validation Accuracy: 0.6890
# Epoch 57, CIFAR-10 Batch 5:  Loss:     0.0316 Validation Accuracy: 0.6770
# Epoch 58, CIFAR-10 Batch 1:  Loss:     0.0757 Validation Accuracy: 0.6898
# Epoch 58, CIFAR-10 Batch 2:  Loss:     0.0519 Validation Accuracy: 0.6866
# Epoch 58, CIFAR-10 Batch 3:  Loss:     0.0605 Validation Accuracy: 0.6930
# Epoch 58, CIFAR-10 Batch 4:  Loss:     0.0461 Validation Accuracy: 0.6852
# Epoch 58, CIFAR-10 Batch 5:  Loss:     0.0331 Validation Accuracy: 0.6860
# Epoch 59, CIFAR-10 Batch 1:  Loss:     0.0793 Validation Accuracy: 0.6788
# Epoch 59, CIFAR-10 Batch 2:  Loss:     0.0528 Validation Accuracy: 0.6864
# Epoch 59, CIFAR-10 Batch 3:  Loss:     0.0738 Validation Accuracy: 0.6882
# Epoch 59, CIFAR-10 Batch 4:  Loss:     0.0455 Validation Accuracy: 0.6776
# Epoch 59, CIFAR-10 Batch 5:  Loss:     0.0430 Validation Accuracy: 0.6672
# Epoch 60, CIFAR-10 Batch 1:  Loss:     0.0870 Validation Accuracy: 0.6812
# Epoch 60, CIFAR-10 Batch 2:  Loss:     0.0418 Validation Accuracy: 0.6756
# Epoch 60, CIFAR-10 Batch 3:  Loss:     0.0446 Validation Accuracy: 0.6888
# Epoch 60, CIFAR-10 Batch 4:  Loss:     0.0423 Validation Accuracy: 0.6862
# Epoch 60, CIFAR-10 Batch 5:  Loss:     0.0292 Validation Accuracy: 0.6664

# %% [markdown]
# # Checkpoint
# The model has been saved to disk.
# ## Test Model
# Test your model against the test dataset.  This will be your final accuracy. You should have an accuracy greater than 50%. If you don't, keep tweaking the model architecture and parameters.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import tensorflow as tf
import pickle
import helper
import random

# Set batch size if not already set
try:
    if batch_size:
        pass
except NameError:
    batch_size = 64

save_model_path = './image_classification'
n_samples = 4
top_n_predictions = 3

def test_model():
    """
    Test the saved model against the test dataset
    """

    test_features, test_labels = pickle.load(open('preprocess_training.p', mode='rb'))
    loaded_graph = tf.Graph()

    with tf.Session(graph=loaded_graph) as sess:
        # Load model
        loader = tf.train.import_meta_graph(save_model_path + '.meta')
        loader.restore(sess, save_model_path)

        # Get Tensors from loaded model
        loaded_x = loaded_graph.get_tensor_by_name('x:0')
        loaded_y = loaded_graph.get_tensor_by_name('y:0')
        loaded_keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')
        loaded_logits = loaded_graph.get_tensor_by_name('logits:0')
        loaded_acc = loaded_graph.get_tensor_by_name('accuracy:0')
        
        # Get accuracy in batches for memory limitations
        test_batch_acc_total = 0
        test_batch_count = 0
        
        for train_feature_batch, train_label_batch in helper.batch_features_labels(test_features, test_labels, batch_size):
            test_batch_acc_total += sess.run(
                loaded_acc,
                feed_dict={loaded_x: train_feature_batch, loaded_y: train_label_batch, loaded_keep_prob: 1.0})
            test_batch_count += 1

        print('Testing Accuracy: {}\n'.format(test_batch_acc_total/test_batch_count))

        # Print Random Samples
        random_test_features, random_test_labels = tuple(zip(*random.sample(list(zip(test_features, test_labels)), n_samples)))
        random_test_predictions = sess.run(
            tf.nn.top_k(tf.nn.softmax(loaded_logits), top_n_predictions),
            feed_dict={loaded_x: random_test_features, loaded_y: random_test_labels, loaded_keep_prob: 1.0})
        helper.display_image_predictions(random_test_features, random_test_labels, random_test_predictions)


test_model()
# Out:
# Testing Accuracy: 0.6627768987341772

# %% [markdown]
# ## Why 50-70% Accuracy?
# You might be wondering why you can't get an accuracy any higher. First things first, 50% isn't bad for a simple CNN.  Pure guessing would get you 10% accuracy. However, you might notice people are getting scores [well above 70%](http://rodrigob.github.io/are_we_there_yet/build/classification_datasets_results.html#43494641522d3130).  That's because we haven't taught you all there is to know about neural networks. We still need to cover a few more techniques.
# ## Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook.  Save the notebook file as "dlnd_image_classification.ipynb" and save it as a HTML file under "File" -> "Download as".  Include the "helper.py" and "problem_unittests.py" files in your submission.
